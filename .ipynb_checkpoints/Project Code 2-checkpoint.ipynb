# %% [markdown]
# **Predicting the best players by strength of players for playing positions**

# %% [markdown]
# **The Problem:** The client, a famous European Football Club wants to have a list of players to consider during transfer season. In case they need to make a transfer, they will bring in a replacement. A major part of player selection depends upon which position the player will play at. Depending on the need of the team, the managers will consider the up and coming players who will suit their need. The client requires us to build an algorithm that will predict the best 20 players for each specific position

# %% [markdown]
# **The Solution:**
#
# **Data:** The data we will use for this problem is sourced from several websites such as
#
# http://football-data.mx-api.enetscores.com/ : scores, lineup, team formation and events
#
# http://www.football-data.co.uk/ : betting odds
#
# http://sofifa.com/ : players and teams attributes from EA Sports FIFA games. FIFA series and all FIFA assets property of EA Sports;
# by Hugomathien and made available on Kaggle at https://www.kaggle.com/hugomathien/soccer
#
# **Cleaning:**
# 1. From the available database, we use the tables 'players' and 'player_attributes' and identify each players preferred position of playing using their X, Y playing coordinates. We create a table of player_positions to make merging of datasets easier
# 2. After merging all the available datasets, we keep only the features we need to predict the performance for a player. We use the feature 'overall_rating' given by FIFA and we calculate the age of each player for the same rating date. This is to understand whether age of the player has impact on player performance. Alternatively, we can also collect rating for each player on the latest date available for the player and use that to correlate age and overall_rating
# 3. We check this data for missing and incorrect values and clean it
#
# **Descriptive Analytics:**
# 1. Test the correlation of age with overall rating and fit a model to predict rating for each player position
# 2. Also test additional data from player attributes dataset like player strength, height, weight etc. to check for correlation with score (overall_rating)
#
# **Modeling:**
# 1. For each position, check assumptions, hypotheses and test
# 2. Fit a suitable model on training data and test on testing data

# %% [markdown]
# Step 1: Importing the data and packages required

# %%
#import packages
import os
import pandas as pd
import sqlite3
import warnings
warnings.filterwarnings("ignore")
import datetime as dt
import scipy.stats as stats
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn

import seaborn as sns

# special matplotlib argument for improved plots
from matplotlib import rcParams
sns.set_style("whitegrid")
sns.set_context("poster")

# %%
#formatting for table displays
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
#connection to database
with sqlite3.connect('/Users/ruhama.ahale/Documents/git_repository/capstone-project big files/database_with_player_positions.sqlite') as con:
    #countries = pd.read_sql_query("SELECT * from Country", con)
    #matches = pd.read_sql_query("SELECT * from Match", con)
    #leagues = pd.read_sql_query("SELECT * from League", con)
    #teams = pd.read_sql_query("SELECT * from Team", con)
    player_attributes = pd.read_sql_query("SELECT * from Player_Attributes", con)
    player_positions = pd.read_sql_query("SELECT * from Player_Positions", con)
    player = pd.read_sql_query("SELECT * from Player", con)

# %% [markdown]
# Step 2: Joining selected table to create final data table

# %%
player.head(3)
# Out:
#    id  player_api_id         player_name  player_fifa_api_id  \
# 0   1         505942  Aaron Appindangoye              218353
# 1   2         155782     Aaron Cresswell              189615
# 2   3         162549         Aaron Doran              186170
#
#               birthday  height  weight
# 0  1992-02-29 00:00:00  182.88     187
# 1  1989-12-15 00:00:00  170.18     146
# 2  1991-05-13 00:00:00  170.18     163

# %%
player_attributes.head(3)
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
# 2   3              218353         505942  2015-09-21 00:00:00            62.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
# 2       66.0          right              medium              medium      49.0
#
#       ...       vision  penalties  marking  standing_tackle  sliding_tackle  \
# 0     ...         54.0       48.0     65.0             69.0            69.0
# 1     ...         54.0       48.0     65.0             69.0            69.0
# 2     ...         54.0       48.0     65.0             66.0            69.0
#
#    gk_diving  gk_handling  gk_kicking  gk_positioning  gk_reflexes
# 0        6.0         11.0        10.0             8.0          8.0
# 1        6.0         11.0        10.0             8.0          8.0
# 2        6.0         11.0        10.0             8.0          8.0
#
# [3 rows x 42 columns]

# %%
player_positions.head(3)
# Out:
#    player_api_id         player_name  matches_played  \
# 0         505942  Aaron Appindangoye               8
# 1         155782     Aaron Cresswell              75
# 2         162549         Aaron Doran             104
#
#    matches_played_in_position  preferred_x_position  preferred_y_position  \
# 0                           8                     6                     3
# 1                          75                     8                     3
# 2                          78                     2                     7
#
#   player_position
# 0     Center Back
# 1       Left Back
# 2    Right Winger

# %%
#merge all player files to get the player details required
player_positions = player_positions[['player_api_id', 'player_name', 'player_position']]
player_attributes_new = player_attributes
player_attributes_new = player_positions.merge(player_attributes_new,on='player_api_id')
player = player[['player_api_id', 'birthday', 'height', 'weight']]
player_attributes_new = player_attributes_new.merge(player,on='player_api_id')
player_attributes_new['birthday_date'] = pd.to_datetime(player_attributes_new['birthday'])
player_attributes_new['date'] = pd.to_datetime(player_attributes_new['date'])
player_attributes_new['age'] = player_attributes_new['date'] - player_attributes_new['birthday_date']
player_attributes_new['age'] = player_attributes_new['age'].astype(dt.timedelta).map(lambda x: np.nan if pd.isnull(x) else x.days)
player_attributes_new['age'] = round(player_attributes_new['age']/365,0)
player_attributes_new = player_attributes_new[player_attributes_new.date >= '2009-07-31']

# %%
player_attributes_new.head(3)
# Out:
#    player_api_id         player_name player_position  id  player_fifa_api_id  \
# 0         505942  Aaron Appindangoye     Center Back   1              218353
# 1         505942  Aaron Appindangoye     Center Back   2              218353
# 2         505942  Aaron Appindangoye     Center Back   3              218353
#
#         date  overall_rating  potential preferred_foot attacking_work_rate  \
# 0 2016-02-18            67.0       71.0          right              medium
# 1 2015-11-19            67.0       71.0          right              medium
# 2 2015-09-21            62.0       66.0          right              medium
#
#    ...  gk_diving  gk_handling  gk_kicking  gk_positioning  gk_reflexes  \
# 0  ...        6.0         11.0        10.0             8.0          8.0
# 1  ...        6.0         11.0        10.0             8.0          8.0
# 2  ...        6.0         11.0        10.0             8.0          8.0
#
#               birthday  height  weight  birthday_date   age
# 0  1992-02-29 00:00:00  182.88     187     1992-02-29  24.0
# 1  1992-02-29 00:00:00  182.88     187     1992-02-29  24.0
# 2  1992-02-29 00:00:00  182.88     187     1992-02-29  24.0
#
# [3 rows x 49 columns]

# %%
player_attributes_new = player_attributes_new[['player_api_id',  'player_name',  'player_position',   'date',  'birthday_date', 'potential', 'overall_rating',  'age', 'finishing',  'heading_accuracy',  'short_passing',  'volleys',  'dribbling',  'curve',  'free_kick_accuracy',  'long_passing',  'ball_control',  'acceleration',  'sprint_speed',  'agility',  'reactions',  'balance',  'shot_power',  'jumping',  'stamina',  'strength',  'long_shots',  'aggression',  'interceptions',  'positioning',  'vision',  'penalties',  'marking',  'standing_tackle',  'sliding_tackle',  'gk_diving',  'gk_handling',  'gk_kicking',  'gk_positioning',  'gk_reflexes',   'height',  'weight']]

player_attributes_new.head()
# Out:
#    player_api_id         player_name player_position       date birthday_date  \
# 0         505942  Aaron Appindangoye     Center Back 2016-02-18    1992-02-29
# 1         505942  Aaron Appindangoye     Center Back 2015-11-19    1992-02-29
# 2         505942  Aaron Appindangoye     Center Back 2015-09-21    1992-02-29
# 3         505942  Aaron Appindangoye     Center Back 2015-03-20    1992-02-29
# 5         155782     Aaron Cresswell       Left Back 2016-04-21    1989-12-15
#
#    potential  overall_rating   age  finishing  heading_accuracy   ...    \
# 0       71.0            67.0  24.0       44.0              71.0   ...
# 1       71.0            67.0  24.0       44.0              71.0   ...
# 2       66.0            62.0  24.0       44.0              71.0   ...
# 3       65.0            61.0  23.0       43.0              70.0   ...
# 5       76.0            74.0  26.0       53.0              58.0   ...
#
#    marking  standing_tackle  sliding_tackle  gk_diving  gk_handling  \
# 0     65.0             69.0            69.0        6.0         11.0
# 1     65.0             69.0            69.0        6.0         11.0
# 2     65.0             66.0            69.0        6.0         11.0
# 3     62.0             63.0            66.0        5.0         10.0
# 5     76.0             75.0            78.0       14.0          7.0
#
#    gk_kicking  gk_positioning  gk_reflexes  height  weight
# 0        10.0             8.0          8.0  182.88     187
# 1        10.0             8.0          8.0  182.88     187
# 2        10.0             8.0          8.0  182.88     187
# 3         9.0             7.0          7.0  182.88     187
# 5         9.0             9.0         12.0  170.18     146
#
# [5 rows x 42 columns]

# %%
#number of unique player in our new database
player_attributes_new.player_api_id.nunique()
# Out:
# 10867

# %%
#save data to csv
#df = pd.DataFrame(player_attributes_new)
#df.to_csv('player_attributes_new2.csv', sep=',', encoding='utf-8')

# %%
#missing values delete
player_attributes_new[player_attributes_new.columns[:]].isnull().sum()
player_attributes_new.isnull().any(axis=1).sum()
#find proportion of missing values
prop_missing = round((player_attributes_new[player_attributes_new.columns[:]].isnull().sum()/player_attributes_new[player_attributes_new.columns[:]].count())*100,2)
prop_missing
player_attributes_new = player_attributes_new.dropna(axis=0, how='any')
player_attributes_new.isnull().any(axis=1).sum()
# Out:
# 0

# %%
#count unique players in each position
player_attributes_new.groupby(player_attributes_new.player_position).player_api_id.nunique()
# Out:
# player_position
# Attacking Midfielder    1001
# Center Back             1713
# Center Forward          1612
# Central Midfielder      1700
# Goalkeeper               919
# Left Back                867
# Left Forward             215
# Left Midfielder          278
# Left Winger              344
# RIght Midfielder         327
# Right Back               956
# Right Forward            226
# Right Winger             424
# Name: player_api_id, dtype: int64

# %%
#select data for one position for analysis
left_back = player_attributes_new[(player_attributes_new.player_position== 'Left Back')]
left_back_avg = left_back.groupby(left_back.player_api_id).mean()
left_back_avg.head()
# Out:
#                potential  overall_rating        age  finishing  \
# player_api_id
# 2790           77.000000       70.000000  36.500000  37.000000
# 3316           65.000000       65.555556  32.222222  50.000000
# 8930           68.785714       66.428571  28.285714  42.571429
# 11242          66.625000       63.375000  25.062500  31.125000
# 11327          72.400000       68.600000  31.800000  60.600000
#
#                heading_accuracy  short_passing    volleys  dribbling  \
# player_api_id
# 2790                  54.500000      69.500000  43.000000  65.000000
# 3316                  64.777778      58.555556  41.888889  58.888889
# 8930                  69.428571      62.142857  53.000000  53.785714
# 11242                 53.625000      62.500000  42.125000  57.500000
# 11327                 33.600000      74.400000  64.800000  73.200000
#
#                    curve  free_kick_accuracy   ...      marking  \
# player_api_id                                  ...
# 2790           67.000000           56.000000   ...    74.500000
# 3316           61.888889           61.111111   ...    59.444444
# 8930           43.000000           47.000000   ...    65.285714
# 11242          46.125000           37.812500   ...    62.000000
# 11327          66.400000           67.600000   ...    55.400000
#
#                standing_tackle  sliding_tackle  gk_diving  gk_handling  \
# player_api_id
# 2790                 75.500000       69.000000   8.000000    17.500000
# 3316                 67.555556       68.333333   7.000000    11.000000
# 8930                 66.000000       65.428571   5.285714    10.714286
# 11242                62.250000       64.437500   5.062500    12.062500
# 11327                54.600000       52.600000  11.800000    10.400000
#
#                gk_kicking  gk_positioning  gk_reflexes  height  weight
# player_api_id
# 2790            40.500000       17.000000    16.500000  175.26     163
# 3316            13.555556        8.000000     7.000000  180.34     159
# 8930             8.785714        9.785714    15.357143  182.88     170
# 11242           11.062500        6.062500     9.062500  177.80     174
# 11327           24.800000        8.800000    14.400000  162.56     146
#
# [5 rows x 37 columns]

# %%
#plot for mean age
plt.hist(left_back_avg.age)
plt.title("Age")
plt.xlabel("Average players per age")
plt.ylabel("Frequency")
plt.show()

# %%
#plot for mean overall_rating
plt.hist(left_back_avg.overall_rating)
plt.title("Overall Rating")
plt.xlabel("Average players per Rating")
plt.ylabel("Frequency")
plt.show()

# %%
#Scatter plot to check relationship between age and rating
plt.scatter(left_back_avg.age, left_back_avg.overall_rating)
plt.xlabel("Player Overall Rating by Age")
plt.ylabel("Age")
plt.title("Rating")

# %%
sns.regplot(y="overall_rating", x="age", data=left_back_avg, fit_reg = True)

# %%
#run pca on left back
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

import plotly.plotly as py
from plotly.graph_objs import *
import plotly.tools as tls

# %%
df = left_back
len(df)
# Out:
# 12369

# %%
df.head()
# Out:
#    player_api_id         player_name player_position       date birthday_date  \
# 0         505942  Aaron Appindangoye     Center Back 2016-02-18    1992-02-29
# 1         505942  Aaron Appindangoye     Center Back 2015-11-19    1992-02-29
# 2         505942  Aaron Appindangoye     Center Back 2015-09-21    1992-02-29
# 3         505942  Aaron Appindangoye     Center Back 2015-03-20    1992-02-29
# 5         155782     Aaron Cresswell       Left Back 2016-04-21    1989-12-15
#
#    overall_rating  potential   age  finishing  heading_accuracy   ...    \
# 0            67.0       71.0  24.0       44.0              71.0   ...
# 1            67.0       71.0  24.0       44.0              71.0   ...
# 2            62.0       66.0  24.0       44.0              71.0   ...
# 3            61.0       65.0  23.0       43.0              70.0   ...
# 5            74.0       76.0  26.0       53.0              58.0   ...
#
#    marking  standing_tackle  sliding_tackle  gk_diving  gk_handling  \
# 0     65.0             69.0            69.0        6.0         11.0
# 1     65.0             69.0            69.0        6.0         11.0
# 2     65.0             66.0            69.0        6.0         11.0
# 3     62.0             63.0            66.0        5.0         10.0
# 5     76.0             75.0            78.0       14.0          7.0
#
#    gk_kicking  gk_positioning  gk_reflexes  height  weight
# 0        10.0             8.0          8.0  182.88     187
# 1        10.0             8.0          8.0  182.88     187
# 2        10.0             8.0          8.0  182.88     187
# 3         9.0             7.0          7.0  182.88     187
# 5         9.0             9.0         12.0  170.18     146
#
# [5 rows x 42 columns]

# %%
#Split data as such:60% - train set, 20% - validation set, 20% - test set:
#train, validate, test = np.split(df.sample(frac=1), [int(.6*len(df)), int(.8*len(df))])

# %%
max_date_score = df.groupby(['player_api_id'], sort=False)['date'].max()
max_date_score = pd.DataFrame(max_date_score.reset_index(name = "date"))
top_10 = max_date_score.merge(df,on=['player_api_id', 'date'])
top_10 = top_10.sort_values(by='overall_rating', ascending=False)
top_10 = top_10.head(10)
top_10
# Out:
#      player_api_id       date         player_name player_position  \
# 204         121633 2016-04-28         David Alaba       Left Back
# 461         150739 2016-03-24          Jordi Alba       Left Back
# 581          28467 2016-05-12             Marcelo       Left Back
# 34          157865 2016-04-21         Alex Sandro       Left Back
# 526          24846 2016-04-07     Leighton Baines       Left Back
# 311          41167 2016-04-21         Filipe Luis       Left Back
# 418          26403 2016-01-28      Jeremy Mathieu       Left Back
# 739         115591 2016-02-25   Ricardo Rodriguez       Left Back
# 697          32569 2016-04-21        Patrice Evra       Left Back
# 104          41092 2015-10-16  Benoit Tremoulinas       Left Back
#
#     birthday_date  potential  overall_rating   age  finishing  \
# 204    1992-06-24       88.0            85.0  24.0       63.0
# 461    1989-03-21       85.0            84.0  27.0       73.0
# 581    1988-05-12       83.0            83.0  28.0       66.0
# 34     1991-01-26       85.0            82.0  25.0       59.0
# 526    1984-12-11       82.0            82.0  31.0       70.0
# 311    1985-08-09       82.0            82.0  31.0       59.0
# 418    1983-10-29       82.0            82.0  32.0       52.0
# 739    1992-08-25       86.0            82.0  24.0       59.0
# 697    1981-05-15       81.0            81.0  35.0       33.0
# 104    1985-12-28       81.0            81.0  30.0       58.0
#
#      heading_accuracy   ...    marking  standing_tackle  sliding_tackle  \
# 204              76.0   ...       82.0             84.0            84.0
# 461              60.0   ...       79.0             84.0            82.0
# 581              69.0   ...       79.0             83.0            86.0
# 34               64.0   ...       78.0             80.0            84.0
# 526              74.0   ...       81.0             82.0            82.0
# 311              66.0   ...       84.0             82.0            85.0
# 418              82.0   ...       83.0             85.0            77.0
# 739              74.0   ...       85.0             83.0            85.0
# 697              76.0   ...       80.0             84.0            86.0
# 104              67.0   ...       79.0             80.0            81.0
#
#      gk_diving  gk_handling  gk_kicking  gk_positioning  gk_reflexes  height  \
# 204        5.0          7.0        14.0            15.0          9.0  180.34
# 461       13.0         15.0        13.0             6.0         13.0  170.18
# 581       12.0          5.0         5.0             5.0          9.0  175.26
# 34         7.0          7.0         9.0            12.0          5.0  180.34
# 526        8.0         15.0        10.0            13.0         12.0  170.18
# 311       11.0         15.0         9.0             9.0          5.0  182.88
# 418       13.0         14.0        10.0             9.0          5.0  187.96
# 739       14.0         13.0        14.0            14.0         11.0  180.34
# 697        3.0          5.0         5.0             5.0          3.0  175.26
# 104        5.0         14.0        11.0            14.0          8.0  172.72
#
#      weight
# 204     168
# 461     150
# 581     165
# 34      172
# 526     154
# 311     170
# 418     185
# 739     170
# 697     163
# 104     143
#
# [10 rows x 42 columns]

# %%
keys = ['player_api_id']
i1 = df.set_index(keys).index
i2 = top_10.set_index(keys).index
df2 = df[i1.isin(i2)]
len(df2)
# Out:
# 240

# %%
df2.groupby(['player_api_id'], sort=False).size()
# Out:
# player_api_id
# 157865    32
# 41092     18
# 121633    32
# 41167     21
# 26403     18
# 150739    16
# 24846     28
# 28467     17
# 32569     30
# 115591    28
# dtype: int64

# %%
df2_p1 = df2[df2.player_api_id == 157865]
df2_p1 = df2_p1.sort_values(by='date', ascending=True)
df2_p1['date_rank'] = range(1, len(df2_p1) + 1)
len(df2_p1)
# Out:
# 32

# %%
#Split the dataset into train_validate_test datasets keeping the end dates in test
#Lets do a 70-20-10 split
#So for 32 observations we split into group of 22-6-4
train_p1 = df2_p1[0:22]
validate_p1 = df2_p1[22:28]
test_p1 = df2_p1[28:32]

# %%
#import modules to run pca
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

import plotly.plotly as py
from plotly.graph_objs import *
import plotly.tools as tls

# %% [markdown]
# Fit model on training data by using PCA to reduce features

# %%
#split train_p1 into x_train and y_train

# %%
x_train = train_p1.ix[:,7:44].values
y_train = train_p1.ix[:,6:7].values

# %%
#Scaling the values
x_train = scale(x_train)

# %%
#run pca

pca = PCA(n_components=34)

pca.fit(x_train)

var= pca.explained_variance_ratio_
#Cumulative Variance explains
var1=np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100)

print(var1)

plt.plot(var1)
plt.show()
# Out:
# [ 71.39  83.    91.64  94.85  96.89  98.28  98.98  99.59  99.79  99.89
#   99.93  99.96  99.97  99.98  99.99  99.99  99.99  99.99  99.99  99.99
#   99.99  99.99]

# %%
#Looking at above plot I'm taking 5 variables
pca = PCA(n_components=5)
pca.fit(x_train)
X1=pca.fit_transform(x_train)

# %%
# Import regression modules
# ols - stands for Ordinary least squares, we'll use this
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
lm = LinearRegression()
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#fit linear regression
lm.fit(X1, y_train)
lm.score(X1, y_train)
# Out:
# 0.99562128879295753

# %%
#data_p1 = pd.DataFrame(np.column_stack([X1,y_train]),columns=['x1','x2', 'x3', 'x4', 'x5', 'y'])

# %%
print('Train features:  ', X1.shape)
# Out:
# Train features:   (22, 5)

# %%
clf = Ridge(alpha=0.001)
clf.fit(X1, y_train)
score = clf.score(X1, y_train)
score
# Out:
# 0.99562128878094569

# %%
ridgereg = Ridge(alpha=0.001,normalize=True)
ridgereg.fit(X1, y_train)
y_pred = ridgereg.predict(X1)
rss = sum((y_pred-y_train)**2)
rss
# Out:
# array([ 2.28222438])

# %%
predicted_scores_r1 = clf.predict(X1)

# %%
#plot
plt.scatter(predicted_scores_r1, y_train)
plt.xlabel("Predicted Score")
plt.ylabel("Actual Score")
plt.title("Relationship between Actual Score and Predicted Score")

# %%
#plot

data_p1 = pd.DataFrame(np.column_stack([X1,y_train]),columns=['x1','x2', 'x3', 'x4', 'x5', 'y'])

ax = data_p1.plot(kind="scatter", x="y",y="x1", color="b", label="x1 vs. x")
data_p1.plot(x="y",y="x2", color="r", label="x2 vs. x", ax=ax)
data_p1.plot( x="y",y="x3", color="g", label="x3 vs. x", ax=ax)
data_p1.plot( x="y",y="x4", color="orange", label="x4 vs. d", ax=ax)
data_p1.plot( x="y",y="x5", color="purple", label="x5 vs. a", ax=ax)

ax.set_xlabel("train_actual_score")
ax.set_ylabel("PCA Components")
plt.show()

# %%
#data_p1['x1']

# %%
#ridge regression model
def ridge_regression(data, predictors, alpha, models_to_plot={}):
    #Fit the model
    ridgereg = Ridge(alpha=alpha,normalize=True)
    ridgereg.fit(X1, y_train)
    y_pred = ridgereg.predict(X1)
    
    #Return the result in pre-defined format
    rss = sum((y_pred-y_train)**2)
    ret = [rss]
    ret.extend([ridgereg.intercept_])
    ret.extend(ridgereg.coef_)
    return ret

#Initialize predictors to be set of 15 powers of x
predictors=X1
#predictors.extend(data_p1['x2','x3', 'x4', 'x5'])

#Set the different values of alpha to be tested
alpha_ridge = [1e-15, 1e-10, 1e-8, 1e-4, 1e-3,1e-2, 1, 5, 10, 20]

#Initialize the dataframe for storing coefficients.
col = ['rss','intercept'] + ['coef_x%d'%i for i in range(1,2)]
ind = ['alpha_%.2g'%alpha_ridge[i] for i in range(0,10)]
coef_matrix_ridge = pd.DataFrame(index=ind, columns=col)

models_to_plot = {1e-15:231, 1e-10:232, 1e-4:233, 1e-3:234, 1e-2:235, 5:236}
for i in range(10):
    coef_matrix_ridge.iloc[i,] = ridge_regression(data_p1, predictors, alpha_ridge[i], models_to_plot)

#Set the display format to be scientific for ease of analysis
pd.options.display.float_format = '{:,.2g}'.format
print(coef_matrix_ridge)
# Out:
#                           rss        intercept  \
# alpha_1e-15   [2.28170660352]  [75.3636363636]
# alpha_1e-10   [2.28170660352]  [75.3636363636]
# alpha_1e-08   [2.28170660352]  [75.3636363636]
# alpha_0.0001  [2.28171179058]  [75.3636363636]
# alpha_0.001   [2.28222437666]  [75.3636363636]
# alpha_0.01    [2.33256526468]  [75.3636363636]
# alpha_1       [131.984007225]  [75.3636363636]
# alpha_5       [362.565874998]  [75.3636363636]
# alpha_10      [431.049642544]  [75.3636363636]
# alpha_20      [472.856946955]  [75.3636363636]
#
#                                                         coef_x1
# alpha_1e-15   [-0.977149803907, -0.484149678439, 0.251344538...
# alpha_1e-10   [-0.977149803809, -0.48414967839, 0.2513445381...
# alpha_1e-08   [-0.977149794135, -0.484149673597, 0.251344535...
# alpha_0.0001  [-0.977052098697, -0.484101268312, 0.251319406...
# alpha_0.001   [-0.976173630276, -0.483666012426, 0.251093444...
# alpha_0.01    [-0.967475053373, -0.479356117266, 0.248855978...
# alpha_1       [-0.488574901953, -0.242074839219, 0.125672269...
# alpha_5       [-0.162858300651, -0.0806916130731, 0.04189075...
# alpha_10      [-0.0888318003552, -0.0440136071308, 0.0228495...
# alpha_20      [-0.0465309430432, -0.0230547465923, 0.0119687...

# %%
#Run the model on validate dataset:
#validate_p1
x_val = validate_p1.ix[:,7:44].values
y_val = validate_p1.ix[:,6:7].values

#Scaling the values
x_val = scale(x_val)

#run pca

pca = PCA(n_components=34)

pca.fit(x_val)

var= pca.explained_variance_ratio_
#Cumulative Variance explains
var1=np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100)

print(var1)

plt.plot(var1)
plt.show()
# Out:
# [  69.97   99.09   99.76  100.    100.    100.  ]

# %%
#Looking at above plot I'm taking 1 component
pca = PCA(n_components=1)
pca.fit(x_val)
X2=pca.fit_transform(x_val)

#fit the ridge regression model with alpha at 0.001
clf = Ridge(alpha=0.001)
clf.fit(X2, y_val)
score = clf.score(X2, y_val)
print('Rsquare:')
print(score)

ridgereg = Ridge(alpha=0.001,normalize=True)
ridgereg.fit(X2, y_val)
y_pred = ridgereg.predict(X2)
rss = sum((y_pred-y_val)**2)
print('RSS:')
print(rss)

#predicted scores for test
#predicted_scores_r1 = clf.predict(X3)
# Out:
# Rsquare:
# 0.998497140595
# RSS:
# [ 0.02005141]

# %%
#run model on test data:
#test_p1
x_test = test_p1.ix[:,7:44].values
y_test = test_p1.ix[:,6:7].values

#Scaling the values
x_test = scale(x_test)

#run pca

pca = PCA(n_components=34)

pca.fit(x_test)

var= pca.explained_variance_ratio_
#Cumulative Variance explains
var1=np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100)

print(var1)

plt.plot(var1)
plt.show()
# Out:
# [  70.34   85.72  100.01  100.01]

# %%
#Looking at above plot I'm taking 5 variables
pca = PCA(n_components=2)
pca.fit(x_test)
X3=pca.fit_transform(x_test)

#fit the ridge regression model with alpha at 0.001
clf = Ridge(alpha=0.001)
clf.fit(X3, y_test)
score = clf.score(X3, y_test)
print('Rsquare:')
print(score)


ridgereg = Ridge(alpha=0.001,normalize=True)
ridgereg.fit(X3, y_test)
y_pred = ridgereg.predict(X3)
rss = sum((y_pred-y_test)**2)
print('RSS:')
print(rss)

#predicted scores for test
predicted_scores = clf.predict(X3)
# Out:
# Rsquare:
# 1.0
# RSS:
# [ 0.]

# %%
#plot predicted vs actual
plt.scatter(predicted_scores, y_test)
plt.xlabel("Predicted Score")
plt.ylabel("Actual Score")
plt.title("Relationship between Actual Score and Predicted Score")

# %% [markdown]
# Fitting model without PCA

# %%
#split dataset
#Split the dataset into train_validate_test datasets keeping the end dates in test
#Lets do a 70-20-10 split
#So for 32 observations we split into group of 22-6-4
train_p1_set2 = df2_p1[0:26]
test_p1_set2 = df2_p1[26:33]
x_train = train_p1_set2.ix[:,7:44].values
y_train = train_p1_set2.ix[:,6:7].values
x_test = test_p1_set2.ix[:,7:44].values
y_test = test_p1_set2.ix[:,6:7].values

# %% [markdown]
# Testing Linear Regression without PCA

# %%
# Import regression modules
# ols - stands for Ordinary least squares, we'll use this
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
lm = LinearRegression()
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#fit linear regression
lm.fit(x_train, y_train)
lm.score(x_train, y_train)
# Out:
# 1.0

# %% [markdown]
# Fitting Ridge Regression without PCA

# %%
#Ridge checking array of alpha values
# create an array of alpha values
alpha_range = 10.**np.arange(-2, 3)
alpha_range


# select the best alpha with RidgeCV
from sklearn.linear_model import RidgeCV
from sklearn import metrics
ridgeregcv = RidgeCV(alphas=alpha_range, normalize=True, scoring='mean_squared_error')
ridgeregcv.fit(x_train, y_train)
ridgeregcv.alpha_


# predict method uses the best alpha value
y_pred = ridgeregcv.predict(x_test)
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 0.684700002605

# %%
ridgeregcv.alpha_
# Out:
# 0.10000000000000001

# %%
score = ridgeregcv.score(x_train, y_train)
print('Rsquare:')
print(score)
# Out:
# Rsquare:
# 0.99855428176
